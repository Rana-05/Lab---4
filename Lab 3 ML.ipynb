# %% [markdown]
# # New Section

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("student_exam_performance.csv")

df.head()
# Out:
#    student_id  hours_studied  attendance_percentage  sleep_hours  exam_score
# 0           1            2.2                     92          7.9          77
# 1           2            2.2                     61          6.4          46
# 2           3            6.6                     98          4.3          44
# 3           4            7.1                     95          8.7          78
# 4           5            6.5                     89          5.2          85

# %%
df.isnull().sum()
# Out:
# student_id               0
# hours_studied            0
# attendance_percentage    0
# sleep_hours              0
# exam_score               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns.duplicated().any()
# Out:
# np.False_

# %%
df.shape
# Out:
# (200, 5)

# %%
df.dtypes
# Out:
# student_id                 int64
# hours_studied            float64
# attendance_percentage      int64
# sleep_hours              float64
# exam_score                 int64
# dtype: object

# %%
df.describe()
# Out:
#        student_id  hours_studied  attendance_percentage  sleep_hours  \
# count  200.000000     200.000000             200.000000    200.00000
# mean   100.500000       4.034000              74.895000      6.54300
# std     57.879185       2.186492              14.367537      1.46375
# min      1.000000       0.600000              50.000000      4.00000
# 25%     50.750000       2.175000              63.000000      5.20000
# 50%    100.500000       3.800000              75.000000      6.50000
# 75%    150.250000       6.100000              86.250000      7.80000
# max    200.000000       8.000000             100.000000      9.00000
#
#        exam_score
# count  200.000000
# mean    61.555000
# std     23.532443
# min     20.000000
# 25%     42.000000
# 50%     62.500000
# 75%     82.250000
# max    100.000000

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["exam_score"], bins=20, kde=True)
plt.title("Distribution of Exam Scores")
plt.xlabel("Exam Score")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["hours_studied"], bins=20, kde=True)
plt.title("Distribution of Hours Studied")
plt.xlabel("Hours Studied")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["attendance_percentage"], bins=20, kde=True)
plt.title("Distribution of Attendance Percentage")
plt.xlabel("Attendance Percentage")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["sleep_hours"], bins=20, kde=True)
plt.title("Distribution of Sleep Hours")
plt.xlabel("Sleep Hours")
plt.ylabel("Frequency")
plt.show()
